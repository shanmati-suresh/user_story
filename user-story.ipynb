# %%
from transformers import pipeline, AutoTokenizer, AutoModelForCausalLM

from huggingface_hub import login

login(token="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")

model_name = "mistralai/Mistral-7B-Instruct-v0.3"
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")

text_gen = pipeline("text-generation", model=model, tokenizer=tokenizer)

client_idea = input("🤖 Please enter your idea or app concept: ")

clarifying_prompt = f"""The client provided this idea: "{client_idea}".
Now generate required smart clarifying questions to better understand the client's goal.
Questions: with Budget and timeframe of the project."""
questions_output = text_gen(clarifying_prompt, max_new_tokens=150, temperature=0.7)[0]["generated_text"]

print("\n📌 Please answer the following questions to clarify your idea:")
questions = questions_output.split("Questions:")[-1].strip().split("\n")
answers = []
for q in questions:
    if q.strip():
        ans = input(q + " ")
        answers.append((q, ans))

story_input = f"Based on this idea: '{client_idea}' and these answers: {answers}, write a user story in this format:\nAs a [user], I want to [goal], so that [benefit] in detail."
user_story = text_gen(story_input, max_new_tokens=1000)[0]["generated_text"].split("\n")[-1]

srs_prompt = f"""Write a Software Requirements Specification (SRS) based on the idea: '{client_idea}' and the answers: {answers}.
Include:
1. Introduction
2. Functional Requirements
3. Non-Functional Requirements
4. User Roles
5. Constraints
"""

srs_doc = text_gen(srs_prompt, max_new_tokens=5000, temperature=0.7)[0]["generated_text"]


print("\n✅ Generated User Story:\n", user_story)
print("\n📄 Generated SRS Document:\n", srs_doc)
# Out:
# 2025-05-30 05:39:36.821956: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1748583577.267007      35 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1748583577.388937      35 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/601 [00:00<?, ?B/s]
# ...
